# %%
import numpy as np
from pathlib import Path

# %matplotlib notebook
import matplotlib.pyplot as plt
import force_calibration_data_processing_script as fdp
import externalforce_weight_comparison_analysis as fwa
import force_error_functions as ferr

# %%
csv_files = [
    'Force_Calibration_04_28_2021_2.csv',
    'Force_Calibration_05_05_2021_0.csv',
    'Force_Calibration_05_05_2021_1.csv',
    'Force_Calibration_05_22_2021_0.csv',
    'Force_Calibration_05_22_2021_3.csv',
    'Force_Calibration_05_22_2021_4.csv',
    'Force_Calibration_05_22_2021_5.csv',
    ]

# csv_files = ['Force_Calibration_05_05_2021_1.csv']

trials = []

print('\nData Sources:')
for filename in csv_files:
    print(filename)
    csv_name = Path.cwd().joinpath(*['Data Files', filename])
    t_data = fdp.get_trial_data(csv_name)
    trials += t_data
# Out:
# Data Sources:
# Force_Calibration_04_28_2021_2.csv
# Force_Calibration_05_05_2021_0.csv
# Force_Calibration_05_05_2021_1.csv
# Force_Calibration_05_22_2021_0.csv
# Force_Calibration_05_22_2021_3.csv
# Force_Calibration_05_22_2021_4.csv
# Force_Calibration_05_22_2021_5.csv

# %%
fdp.force_data_plotter_2D_superimpose(trials)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fdp.force_data_plotter_3D(trials)
# Out:
# <img src="data:image/png;base64,..." width="640">
